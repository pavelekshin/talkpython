# %%
pip -V
# Out:
# pip 23.2.1 from /home/pve/repos/pycharm/project1-plotly/venv/lib/python3.10/site-packages/pip (python 3.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import re

# %%
df = pd.read_csv("data/marvel-wikia-data.csv")
df.head(5)
#df.tail(10)
# Out:
#    page_id                                 name  \
# 0     1678            Spider-Man (Peter Parker)
# 1     7139      Captain America (Steven Rogers)
# 2    64786  Wolverine (James \"Logan\" Howlett)
# 3     1868    Iron Man (Anthony \"Tony\" Stark)
# 4     2460                  Thor (Thor Odinson)
#
#                                    urlslug                ID  \
# 0              \/Spider-Man_(Peter_Parker)   Secret Identity
# 1        \/Captain_America_(Steven_Rogers)   Public Identity
# 2  \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3    \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                    \/Thor_(Thor_Odinson)  No Dual Identity
#
#                 ALIGN         EYE        HAIR              SEX  GSM  \
# 0     Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1     Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2  Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# ...

# %% [markdown]
#     '''get the most popular character by number of appearances accept an argument of n (int) of most popular characters
#     to return (leave default of 5)'''

# %%
df.sort_values(by=["APPEARANCES"], ascending=False).head(5)
# Out:
#    page_id                                 name  \
# 0     1678            Spider-Man (Peter Parker)
# 1     7139      Captain America (Steven Rogers)
# 2    64786  Wolverine (James \"Logan\" Howlett)
# 3     1868    Iron Man (Anthony \"Tony\" Stark)
# 4     2460                  Thor (Thor Odinson)
#
#                                    urlslug                ID  \
# 0              \/Spider-Man_(Peter_Parker)   Secret Identity
# 1        \/Captain_America_(Steven_Rogers)   Public Identity
# 2  \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3    \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                    \/Thor_(Thor_Odinson)  No Dual Identity
#
#                 ALIGN         EYE        HAIR              SEX  GSM  \
# 0     Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1     Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2  Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# ...

# %% [markdown]
#     '''Get the year with most and least new characters introduced respectively,use either the 'FIRST APPEARANCE' or 'Year' column in the csv data, or the 'year' attribute of the namedtuple, return a tuple of (max_year, min_year) '''
#
# #min_max_year_hero_apper = df.groupby(by=["Year"]).count().sort_values(by=["FIRST APPEARANCE"]).reset_index()
# #min_max_year_hero_apper.loc[[0,min_max_year_hero_apper.index[-1]],["Year","APPEARANCES"]]

# %%
df["Year"].value_counts().reset_index().iloc[[0,-1]]
# Out:
#       Year  count
# 0   1993.0    554
# 74  1958.0      2

# %% [markdown]
#     '''Get the percentage of female characters '''

# %%
df["SEX"].value_counts(normalize=True).apply(lambda x: f"{x:.3f}").reset_index()
# Out:
#                       SEX proportion
# 0         Male Characters      0.750
# 1       Female Characters      0.247
# 2      Agender Characters      0.003
# 3  Genderfluid Characters      0.000

# %% [markdown]
#     '''Return dictionary of not binary characters'''

# %%
df.loc[df['GSM'].notnull() == True, ['name','GSM']].to_dict('split', index=False)
df.groupby("GSM", as_index=False).agg(heroes=("name", list),count=("GSM", "size")).sort_values(['count'],ascending=False, ignore_index=True)
# Out:
#                       GSM                                             heroes  \
# 0   Homosexual Characters  [Jean-Paul Beaubier (Earth-616), Chili Storm (...
# 1     Bisexual Characters  [Natalia Romanova (Earth-616), Hercules (Earth...
# 2  Transgender Characters  [Tong (Moloid) (Earth-616), Jessie Drake (Eart...
# 3  Genderfluid Characters                                [Xavin (Earth-616)]
# 4    Pansexual Characters                          [Julie Power (Earth-616)]
# 5           Transvestites                           [Deadpool (Wade Wilson)]
#
#    count
# 0     66
# 1     19
# 2      2
# 3      1
# 4      1
# 5      1

# %% [markdown]
#     '''Return a dictionary of bad vs good vs neutral characters.
#        This function receives an arg 'sex' and should be validated
#        to only receive 'male' or 'female' as valid inputs (should
#        be case insensitive, so could also pass it MALE)
#
#        The expected result should be a the following dict. The values are
#        rounded (int) percentages (values made up here):
#
#        expected = {'Bad Characters': 33,
#                    'Good Characters': 33,
#                    'Neutral Characters': 33})

# %%
df2 = []
for sex in ["male", "female"]:
    df2.append(df[df["SEX"].str.contains(r'\b{}\b'.format(sex), case=False, regex=True
                         ) == True].value_counts("ALIGN",normalize=True).apply(lambda x: f"{x*100:.2f}").reset_index())

# %%
pd.concat(df2, keys=["male", "female"],sort=True, axis=0).rename(columns={"ALIGN": "characters"})
# Out:
#                   characters proportion
# male   0      Bad Characters      54.78
#        1     Good Characters      30.44
#        2  Neutral Characters      14.78
# female 0     Good Characters      48.75
#        1      Bad Characters      30.95
#        2  Neutral Characters      20.30
